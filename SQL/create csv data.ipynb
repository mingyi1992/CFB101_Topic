# %%
import csv

# %% [markdown]
# ### 隱性飢餓症狀

# %%
list = [["id","缺乏營養種類","症狀"],
        [1,"維生素A","眼睛乾澀"],
        [2,"維生素A","夜盲症"],
        [3,"維生素A","皮膚乾燥"],
        [4,"維生素A","腸胃不適"],
        [5,"維生素A","記憶力下降"],
        [6,"維生素A","失眠"],
        [7,"維生素B1","食慾不振"],
        [8,"維生素B1","焦慮"],
        [9,"維生素B1","水腫"],
        [10,"維生素B1","腹瀉"],
        [11,"維生素B1","記憶力下降"],
        [12,"維生素B1","疲倦"],
        [13,"維生素B2","疲倦"],
        [14,"維生素B2","口腔發炎"],
        [15,"維生素B2","頭暈"],
        [16,"維生素B6","口腔發炎"],
        [17,"維生素B6","貧血"],
        [18,"維生素B6","抽筋"],
        [19,"維生素B12","貧血"],
        [20,"維生素B12","疲倦"],
        [21,"維生素B12","食慾不振"],
        [22,"維生素B12","腸胃不適"],
        [23,"維生素B12","腹瀉"],
        [24,"維生素B12","焦慮"],
        [25,"維生素B12","臉色蒼白"],
        [26,"維生素B12","手腳刺痛"],
        [27,"維生素B12","口腔發炎"],
        [28,"維生素C","疲勞"],
        [29,"維生素C","瘀血"],
        [30,"維生素C","牙齦出血"],
        [31,"維生素C","消化不良"],
        [32,"維生素C","關節疼痛"],
        [33,"維生素C","自癒力低下"],
        [34,"維生素D","骨質疏鬆"],
        [35,"維生素D","焦慮"],
        [36,"維生素D","皮膚乾燥"],
        [37,"維生素D","肌肉痠痛"],
        [38,"維生素E","水腫"],
        [39,"維生素E","四肢無力"],
        [40,"維生素E","貧血"],
        [41,"鐵","貧血"],
        [42,"鐵","疲倦"],
        [43,"鐵","食慾不振"],
        [44,"鐵","心悸"],
        [45,"鐵","臉色蒼白"],
        [46,"鐵","掉髮"],
        [47,"鐵","焦慮"],
        [48,"鋅","自癒力低下"],
        [49,"鋅","食慾不振"],
        [50,"鋅","免疫力下降"],
        [51,"鋅","味覺遲鈍"],
        [52,"銅","疲勞"],
        [53,"銅","免疫力下降"],
        [54,"銅","骨質疏鬆"],
        [55,"銅","記憶力下降"],
        [56,"銅","皮膚蒼白"],
        [57,"鈉","頭痛"],
        [58,"鈉","心悸"],
        [59,"鎂","焦慮"],
        [60,"鎂","疲勞"],
        [61,"鎂","失眠"],
        [62,"鎂","肌肉痠痛"],
        [63,"鎂","抽筋"],
        [64,"磷","骨質疏鬆"],
        [65,"磷","食慾不振"],
        [66,"磷","肌肉痠痛"],
        [67,"磷","疲倦"],
        [68,"鉻","骨質疏鬆"],
        [69,"鉻","焦慮"],
        [70,"鉻","抽筋"],
        [71,"鉀","抽筋"],
        [72,"鉀","水腫"],
        [73,"鉀","疲倦"],
        [74,"鉀","心悸"],
        [75,"鉀","食慾不振"],
        [76,"鉀","焦慮"],
        [77,"葉酸","貧血"],
        [78,"葉酸","食慾不振"],
        [79,"鈣","焦慮"],
        [80,"鈣","肌肉痠痛"],
        [81,"鈣","抽筋"],
        [82,"鈣","骨質疏鬆"],
        [83,"鈣","頻尿"],
        [84,"鈣","視力模糊"],
        [85,"鈣","失眠"],
        [86,"蛋白質","免疫力下降"],
        [87,"蛋白質","消化不良"],
        [88,"蛋白質","貧血"],
        [89,"蛋白質","水腫"],
        [90,"蛋白質","食慾不振"],
        [91,"蛋白質","疲倦"],
        [92,"蛋白質","肌肉痠痛"],
        [93,"蛋白質","皮膚乾燥"],
        [94,"膳食纖維","便祕"],
        [95,"膳食纖維","屁味惡臭"],
        [96,"錳","抽筋"],
        [97,"錳","疲倦"],
        [98,"飽和脂肪","皮膚粗糙"],
        [99,"飽和脂肪","掉髮"]]
with open('Hidden_hunger.csv', 'w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerows(list)

# %% [markdown]
# ### 熟食營養表(單位g；cholesterol 跟 Na 為 mg)

# %%
list = [['food_name','calories','carbohydrates','protein','fat','saturated_fat','cholesterol','filber','Na'],
        ['bean_sprout',33,5.4,3.1,0.5,0,0,1.7,34],
        ['dried_tofu',191,7,19.3,9.7,0,0,2.2,445],
        ['tofu skin',231,4.1,21.8,13.7,1.9,0,0.8,4],
        ['cabbage',20,4.3,1.4,0.1,0,0,1.6,4],
        ['cauliflower',26,5.1,2.7,0.1,0,0,3.2,8],
        ['Broccoli',27,4.3,3.5,0.4,0,0,3.7,14],
        ['soy sauce braised egg',186,4.7,15.5,11.9,0,523,0,548],
        ['Fried chicken legs',180,8,16,10,3,35,0,390],
        ['Roasted chicken leg',229,0,24.9,13.2,3.82,140,0,86],
        ['Fried pork ribs',251,19.8,12.9,13.5,0,22,1,583],
        ['steak',250,0,17.3,19.5,0,64,0,67],
        ['Fried chicken chop',220,2,31,9,2.4,87,0,74],
        ['anttree',368.59,27.01,6.53,26.22,2.12,28.87,0.74,354.66],
        ['bamboo shoot',19,3.6,1,0.5,0,0,3.5,360],
        ['Kelp Bud',16,5.6,1.9,0.2,0,0,3.6,610],
        ['Vegetarian ham',231,6.6,13.2,17,0,0,3.3,775],
        ['Diced ham',200,1.3,16.7,16,5.89,52,0,1050],
        ['water_spinach',36,5.46,1.66,1.13,0.1,0.16,2.26,281],
        ['Sauerkraut',18,2,0,0,0,0,0,1775],
        ['soy chicken leg',141,4,20,5,0,0,0,150],
        ['Tomato scrambled eggs',94,14,2,2,0,0,0,60],
        ['Scrambled Eggs with Carrots',168,4,6,14,0,0,1,0],
        ['Fried eggplant',68,7,1,4,0,0,1,0],
        ['sausage',350,12.2,17.1,26.1,0,65,0,974],
        ['sweet potato leaves',63.45,10.88,3.43,0.51,0,0,2.72,582.83],
        ['poached_egg',23.5,2.6,1.1,1,0,0,0,15.4],
        ['Green bean',3.6,0,1.6,0.3,0.08,0,0,3.2],
        ['Gourd',18,4.2,0.4,0.1,0,0,1.2,3],
        ['Brassica chinensis',13,2.1,1,0.3,0,0,1.8,40],
        ['Bok Coy',16,2.2,1.7,0.3,0,0,2.1,37],
        ['spinach',22,3,2.1,0.5,0.04,0,2.4,54],
        ['kelp',16,3.3,0.7,0.2,0,0,3,606],
        ['fried tofu',150,0.9,10.7,11.3,2.09,0,0.7,3],
        ['fried tempura',95.26,16.3,3.02,2.07,0.09,3.36,1.85,490.25],
        ['pea',93,15.3,6.9,0.4,0.05,0,7.7,1]]
with open('food_energe.csv', 'w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerows(list)
